# %% [markdown]
# ## Crawling사이트

# %%
crawling_urls = {'공공체육시설_시설별': "http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-1116&srvType=S&serviceKind=1&currentPageNo=1&searchValue=&searchKey=null",
                 '산과공원': "https://data.seoul.go.kr/dataList/datasetView.do?infId=OA-12962&srvType=A&serviceKind=1&currentPageNo=1",
                 '체육회': "https://www.seoulsports.or.kr/home/homeIndex.do",
                 '공공체육시설_종목별': "http://data.seoul.go.kr/dataList/datasetView.do?infId=OA-1221&srvType=S&serviceKind=1&currentPageNo=1&searchValue=&searchKey=null",
                }

# %%
import requests
from selenium import webdriver
import time
import pandas as pd
import os
import os.path
import glob

# %% [markdown]
# ### 산과공원

# %%
#웹드라이버 실행 및 페이지 이동
driver = webdriver.Chrome()
driver.get(crawling_urls['산과공원'])
time.sleep(5)

driver.find_element_by_css_selector("#tabSheet").click()
time.sleep(3)
    
#csv파일 다운로드 버튼 클릭하기
driver.find_element_by_css_selector("#Wrapfilter > span:nth-child(3)").click()
time.sleep(3)

driver.quit()

# %%
#다운받은 csv파일 열기
_dir = "/Users/jooyoungson/Downloads/"
files = glob.glob('{}/*.csv'.format(_dir))
print(files)

#csv파일을 dataframe으로 변환하기
f_M_park = pd.read_csv(files[len(files)-1])
f_M_park.head(3)
# Out:
# ['/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어) (1).csv', '/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어).csv', '/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어) (2).csv']
#               키             명칭   대분류  \
# 0  BE_IW14-0020  진관내동 생태경관보전지역  생태탐방
# 1  BE_IW14-0109           안산공원  산과공원
# 2  BE_IW14-0110          여의도공원  산과공원
#
#                                            주소   행정 시  행정 구  행정 동  \
# 0  은평구 진관동 282-1번지 일대(북한산국립공원 북한산성 입구 주변 습지 )  서울특별시   은평구   진관동
# 1                     서울특별시 서대문구 홍제동 산33번지 일대  서울특별시  서대문구  홍제1동
# 2                서울특별시 영등포구 여의공원로68(여의도동 2번지)  서울특별시  영등포구   여의동
#
#                          대표전화      면적            지정일  \
# 0  02-2115-7550~5 02-350-1397  16639㎡  2002년 12월 30일
# 1                 02-330-1395     NaN            NaN
# 2                 02-761-4079     NaN            NaN
#
#                                                 교툥안내
# 0  지하철 3호선 구파발역 1번 출구에서 704번 34번 버스를 타고 북한산성 입구에서...
# 1                                                NaN
# 2                                                NaN

# %%
f_M_park.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 11 columns):
# 키       145 non-null object
# 명칭      145 non-null object
# 대분류     145 non-null object
# 주소      145 non-null object
# 행정 시    138 non-null object
# 행정 구    138 non-null object
# 행정 동    138 non-null object
# 대표전화    140 non-null object
# 면적      24 non-null object
# 지정일     20 non-null object
# 교툥안내    24 non-null object
# dtypes: object(11)
# memory usage: 12.5+ KB

# %%
f_M_park.columns
# Out:
# Index(['키', '명칭', '대분류', '주소', '행정 시', '행정 구', '행정 동', '대표전화', '면적', '지정일',
#        '교툥안내'],
#       dtype='object')

# %%
#address = f_M_park['주소']
f_M_park.head(1)
# Out:
#               키             명칭   대분류  \
# 0  BE_IW14-0020  진관내동 생태경관보전지역  생태탐방
#
#                                            주소   행정 시 행정 구 행정 동  \
# 0  은평구 진관동 282-1번지 일대(북한산국립공원 북한산성 입구 주변 습지 )  서울특별시  은평구  진관동
#
#                          대표전화      면적            지정일  \
# 0  02-2115-7550~5 02-350-1397  16639㎡  2002년 12월 30일
#
#                                                 교툥안내
# 0  지하철 3호선 구파발역 1번 출구에서 704번 34번 버스를 타고 북한산성 입구에서...

# %%
f_M_park_1 = f_M_park[['명칭','대분류','주소','대표전화','교툥안내']]

#f_public_T1= f_public_f1.dropna(axis=0)
#종목시설명은 시설명 내의 위치를 설명하므로 뺀다. 
f_M_park_1.head(3)
# Out:
#               명칭   대분류                                          주소  \
# 0  진관내동 생태경관보전지역  생태탐방  은평구 진관동 282-1번지 일대(북한산국립공원 북한산성 입구 주변 습지 )
# 1           안산공원  산과공원                     서울특별시 서대문구 홍제동 산33번지 일대
# 2          여의도공원  산과공원                서울특별시 영등포구 여의공원로68(여의도동 2번지)
#
#                          대표전화  \
# 0  02-2115-7550~5 02-350-1397
# 1                 02-330-1395
# 2                 02-761-4079
#
#                                                 교툥안내
# 0  지하철 3호선 구파발역 1번 출구에서 704번 34번 버스를 타고 북한산성 입구에서...
# 1                                                NaN
# 2                                                NaN

# %%
f_M_park_1.dropna(axis=0)
# Out:
#                   명칭   대분류                                           주소  \
# 0      진관내동 생태경관보전지역  생태탐방   은평구 진관동 282-1번지 일대(북한산국립공원 북한산성 입구 주변 습지 )
# 38      고덕동 생태경관보전지역  생태탐방           강동구 고덕동 396일대(암사정수장~하남시계 구간의 한강수변)
# 39   청계산원터골 생태경관보전지역  생태탐방    서초구 원지동 산4-38번지 일대(청계산 도시자연공원내 원터골 주변 산림)
# 40      청계천하류 철새보호구역  생태탐방                           고산자교 ~ 청계천 중랑천 합류부
# 41      안양천하류 철새보호구역  생태탐방                      오목교 ~ 목동교 양안(목동종합운동장 옆)
# 42   불암산삼육대 생태경관보전지역  생태탐방         노원구 공릉동 산223-1번지 일대(삼육대학교 뒷산 서어나무군락)
# 43    창덕궁후원 생태경관보전지역  생태탐방            종로구 와룡동 2-71번지 일대(창덕궁내 옥류천 주변 산림)
# 44       봉산 생태경관보전지역  생태탐방       은평구 신사동 산93-16번지 일대(봉산 도시자연공원내 팥배나무군락)
# 45      인왕산 생태경관보전지역  생태탐방          서대문구 홍제동 산1-1번지 일대 종로구 옥인동 산3-14 일대
# 46          아차산 생태공원  생태탐방                          서울특별시 광진구 광장동 307번지
# 47          길동자연생태공원  생태탐방                             서울특별시 강동구 길동 3번지
# 48        여의도샛강 생태공원  생태탐방                         영등포구 여의도동(서울교 ~ 여의교)
# 49          강서습지생태공원  생태탐방             강서구 개화동 168-2(방화대교 하류 ~ 행주대교 상류)
# 50        우면산 자연생태공원  생태탐방                                서초구 우면동 산34-1
# 51             월드컵공원  생태탐방                          서울특별시 마포구 상암동 549번지
# 52     한강밤섬 생태경관보전지역  생태탐방  윗밤섬-영등포구 여의도동 84번지 일대 아랫밤섬-마포구 당인동 313번지 일대
# 53      둔촌동 생태경관보전지역  생태탐방           강동구 둔촌동 212번지 일대(둔촌주공아파트 뒤편 오리나무숲)
# 54      방이동 생태경관보전지역  생태탐방         송파구 방이동 443-8번지 일대(올림픽선수촌 아파트 뒤편 습지)
# 55       탄천 생태경관보전지역  생태탐방                       강남구~송파구 경계하천(탄천2교~대곡교)
# 56      암사동 생태경관보전지역  생태탐방       강동구 암사동 624-1번지 일대(한강시민공원 광나루지구내 갈대군락)
# 57      헌인릉 생태경관보전지역  생태탐방                 서초구 내곡동 산13-1 일대(헌인릉내 오리나무숲)
# 58       남산 생태경관보전지역  생태탐방         중구 예장동 산5-6번지 일대(북사면 신갈나무림 남사면 소나무숲)
# 143              양재천  생태탐방                       서울특별시 강남구 영동2교 ~ 탄천합류부
# 144     중랑천하류 철새보호구역  생태탐방               중랑천 한강 합류부~중랑천 청계천 합류부(서울숲 서쪽)
#
#                                               대표전화  \
# 0                       02-2115-7550~5 02-350-1397
# 38                   02-2115-7550~5 02-3780-0865~6
# 39                      02-2115-7550~5 02-570-6396
# 40                     02-2115-7550~5 02-2290-6851
# 41       02-2115-7550~5  02-2650-3590 02-2670-4131
# 42                      02-2115-7550~5 02-950-3889
# 43   02-2115-7550~5 02-731-1460~2 02-762-8261/9513
# 44                      02-2115-7550~5 02-350-1397
# 45        02-2115-7550~5 02-731-1460~2 02-330-1395
# 46                         02-450-7773 02-450-1192
# 47                                     02-472-2770
# 48                                  02-3780-0570~1
# 49                                  02-3780-0621~3
# 50                        02- 570-6395 02-570-6379
# 51                                   02-300-5524~6
# 52                   02-2115-7550~5 02-3780-0793~4
# 53                      02-2115-7550~5 02-480-1395
# 54                      02-2115-7550~5 02-410-3395
# 55          02-2115-7550~5 02-445-1416 02-410-3395
# 56                   02-2115-7550~5 02-3780-0865~6
# 57          02-2115-7550~5 02-570-6396 02-445-0347
# 58                     02-2115-7550~5 02-3783-5960
# 143                                    02-445-1416
# 144                    02-2115-7550~5 02-2290-6851
#
#                                                   교툥안내
# 0    지하철 3호선 구파발역 1번 출구에서 704번 34번 버스를 타고 북한산성 입구에서...
# 38   올림픽대로 미사리 방향 하일I.C 500m 이전 강동구 음식물재활용센터 부지로 진입...
# 39   지하철 3호선 양재역 7번 출구로 나와 4432번 버스를 타고 원터골 입구에서 하차...
# 40                     지하철 2호선 신답역 지하철 5호선 마장역에서 도보 5분
# 41                        지하철 5호선 오목교역에서 안양천방향으로 도보 5분
# 42   지하철 1호선 석계역 4번 출구 7호선 태릉입구역 7번 출구로 나와 1155 115...
# 43              지하철 1호선 종로 3가역 6번 출구 지하철 3호선 안국역 3번 출구
# 44                    지하철 6호선 증산역 4번 출구에서 은평터널방향 도보 2㎞
# 45                지하철 3호선 경복궁역 하차 등산진입로인 사직공원까지 도보로 5분
# 46   지하철 5호선 광나루역 1번 출구에서 광장중학교방향으로 도보 15분 지하철 5호선 ...
# 47                    지하철 5호선 강동역 4번 출구 천호역 6번 출구 버스이용
# 48                    지하철 5호선 여의도역 1번 출구로 나와 약 600m 직진
# 49            지하철 5호선 방화역 2번출구로 나와 6번 마을버스 타고 개화육갑문 하차
# 50        지하철 3호선 양재역 7번 출구로 나와 일반버스 3412번을 타고 종점에서 하차
# 51                              지하철 6호선 월드컵경기장 1 2번 출구
# 52   지하철 5호선 여의나루역 2 3번 출구에서 서강대교 방면 도보로 10분 (한강 여의...
# 53             지하철 5호선 둔촌역 2번 출구에서 둔촌주공아파트 방향으로 도보 15분
# 54        지하철 5호선 올림픽공원역 2번 출구에서 올림픽선수촌아파트 방향으로 도보 15분
# 55               지하철 3호선 수서역(광평교) 학여울역(탄천2교) 하차 도보 15분
# 56                 8호선 암사역 3 4번 출구에서 천호2육갑문방향으로 도보 15분
# 57    지하철 3호선 양재역 7번 출구로 2호선 강남역 6번 출구로 나와 4422번 버스 이용
# 58   지하철 1호선 서울역 4번 출구 회현역 4번 출구 도보 20분 ※ 순환버스(02번)...
# 143              지하철 3호선 도곡역 삼성타워팰리스 방면으로 나와 영동 4교 진입로
# 144              국철 응봉역에서 도보로 3분 지하철 2호선 한양대역에서 도보로 2분

# %%
f_M_park_1.to_csv('M_park_T1.csv')

# %% [markdown]
# ### 공공체육시설-시설별

# %%
#웹드라이버 실행 및 페이지 이동
driver = webdriver.Chrome()
driver.get(crawling_urls['공공체육시설_시설별'])
time.sleep(5)

driver.find_element_by_css_selector("#tabSheet").click()
time.sleep(3)
    
#csv파일 다운로드 버튼 클릭하기
driver.find_element_by_css_selector("#Wrapfilter > span:nth-child(3)").click()
time.sleep(3)

driver.quit()

# %%
#다운받은 csv파일 열기
_dir = "/Users/jooyoungson/Downloads/"
files = glob.glob('{}/*.csv'.format(_dir))
print(files)

#csv파일을 dataframe으로 변환하기
f_public_f = pd.read_csv(files[len(files)-1])
f_public_f.head(3)
# Out:
# ['/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어) (1).csv', '/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어).csv', '/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어) (2).csv', '/Users/jooyoungson/Downloads/서울시 공공 체육시설별 종목시설명 정보.csv']
#           시설명  일련번호          시설키   종목시설명           종목시설키   종목명 종목키   위치 면적(㎡)  \
# 0      영희초등학교   433  GN10100PUSM     체육관  GN10100PUSM101  학교체육  SG  NaN   NaN
# 1      포이초등학교   438  GN10101PUSM     헬스장  GN10101PUSM103    헬스  HE  NaN   NaN
# 2  한강시민공원강서지구   615  GS10173PUEF  체력단련기구  GS10173PUEF104    헬스  HE  NaN   NaN
#
#     규격  ... 이용기간                                               이용시간 이용료(원)  \
# 0  NaN  ...  NaN                                                NaN    NaN
# 1  NaN  ...  NaN                                                NaN    NaN
# 2  NaN  ...  NaN  06:00~20:00(4~9월 : 06:00~20:00 1~3 10~12월 : 07...    NaN
#
#     용도   비고 대관링크주소                                              이미지파일  \
# 0  NaN  NaN    NaN                                                NaN
# 1  NaN  NaN    NaN                                                NaN
# 2  NaN  NaN    NaN  http://hangang.seoul.go.kr/park_gangseo/images...
#
#   선별방법(선착순-1,추첨순-2) 유의사항 이용단위
# 0               NaN  NaN  NaN
# 1               NaN  NaN  NaN
# 2               NaN  NaN  NaN
#
# [3 rows x 24 columns]

# %%
f_public_f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 24 columns):
# 시설명                  1310 non-null object
# 일련번호                 1310 non-null int64
# 시설키                  1310 non-null object
# 종목시설명                1310 non-null object
# 종목시설키                1310 non-null object
# 종목명                  1302 non-null object
# 종목키                  1303 non-null object
# 위치                   849 non-null object
# 면적(㎡)                428 non-null object
# 규격                   411 non-null object
# 연면적(㎡)               107 non-null object
# 문의전화                 515 non-null object
# 수용인원(정원)             70 non-null object
# 이용대상                 252 non-null object
# 이용기간                 121 non-null object
# 이용시간                 320 non-null object
# 이용료(원)               303 non-null object
# 용도                   188 non-null object
# 비고                   306 non-null object
# 대관링크주소               121 non-null object
# 이미지파일                825 non-null object
# 선별방법(선착순-1,추첨순-2)    222 non-null object
# 유의사항                 263 non-null object
# 이용단위                 240 non-null object
# dtypes: int64(1), object(23)
# memory usage: 245.7+ KB

# %%
#f_public_f['시설명']

# %%
#f_public_f.describe()
#a = f_public_f.groupby('시설명')
f_public_f.columns

##pd.pivot_table(f_public_f, values='시설명', )
##pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# Index(['시설명', '일련번호', '시설키', '종목시설명', '종목시설키', '종목명', '종목키', '위치', '면적(㎡)',
#        '규격', '연면적(㎡)', '문의전화', '수용인원(정원)', '이용대상', '이용기간', '이용시간', '이용료(원)',
#        '용도', '비고', '대관링크주소', '이미지파일', '선별방법(선착순-1,추첨순-2)', '유의사항', '이용단위'],
#       dtype='object')

# %%
#f_public_f.groupby('시설명').count()

# %%
#f_public_f.drop(['이미지파일','비고','용도','종목키','위치','면적(㎡)','유의사항','종목시설키','일련번호','이용기간','이용대상','수용인원(정원)','규격','시설키','이용료(원)'], axis='columns', inplace=True)

# %%
f_public_f1 = f_public_f[['시설명','문의전화','종목명','선별방법(선착순-1,추첨순-2)']]
f_public_f1
f_public_T1= f_public_f1.dropna(axis=0)
#종목시설명은 시설명 내의 위치를 설명하므로 뺀다. 
f_public_T1
# Out:
#                 시설명                         문의전화    종목명  \
# 13           용마폭포공원                 02-436-3466      축구
# 15        중랑구립잔디운동장                 02-2094-2949     축구
# 19          안양천체육시설                 02-2652-9998     축구
# 21            월드컵공원                  02-300-5521     축구
# 22            월드컵공원                 02-304-3212      골프
# 23            월드컵공원                 02-3153-8375     축구
# 24            월드컵공원                  02-300-5521    테니스
# 35           목동테니스장                 02-2643-0686    테니스
# 40          안양천체육시설                 02-2620-3400     야구
# 42          안양천체육시설                 02-2652-9992    인라인
# 43          안양천체육시설                 02-2652-9993    인라인
# 44          안양천체육시설                 02-2652-9998     축구
# 46          안양천체육시설                 02-2652-9999     축구
# 47          안양천체육시설                02-2652-10000     축구
# 48          안양천체육시설                02-2652-10001   학교체육
# 69       공릉동다목적풋살구장                 02-2116-3779     풋살
# 70        노해근린공원운동장                 02-2116-3943     축구
# 71           마들스타디움                  02-930-0070     축구
# 72           마들스타디움                  02-930-9106    테니스
# 79          초안산근린공원                  02-900-8691     축구
# 120     서대문구립인조잔디구장                  02-360-8685     축구
# 121      송파구여성전용축구장                  02-412-5969     축구
# 128        올림픽올팍축구장                  02-410-1673     축구
# 134         천마공원축구장                  02-403-2395     축구
# 144           뚝섬서울숲                  02-460-2907     축구
# 148           뚝섬서울숲                  02-460-2907    테니스
# 160     한강시민공원광나루지구                 02-3780-0501     야구
# 164        근로청소년복지관                  02-899-0003     축구
# 166   동명근린공원인조잔디축구장                  02-428-2020     축구
# 169      구의야구공원 야구장                 02-3436-2889     야구
# ...             ...                          ...    ...
# 969        역삼청소년수련관                  02-550-3615     농구
# 978        금천청소년수련관                  02-803-1318     헬스
# 980         강동청소년회관               02-3426-6211~3     댄스
# 981         강동청소년회관               02-3426-6211~3     헬스
# 982         강동청소년회관               02-3426-6211~3     댄스
# 985        역삼청소년수련관                  02-550-3615     댄스
# 1042       화곡청소년수련관                 02-2061-3234     체조
# 1043       서울청소년수련관                 02-2266-0875     헬스
# 1047        영롱이억새구장                 02-2670-3522     축구
# 1060        탄천물재생센터  02-3410-9738/011-9114-3633     테니스
# 1061        탄천물재생센터  02-3410-9738/011-9114-3633      족구
# 1063        영롱이억새구장                 02-2670-3522     축구
# 1065        탄천물재생센터   02-3410-9738/011-9114-3633     농구
# 1066       화곡청소년수련관                 02-2061-3234     헬스
# 1070       중구청소년수련관                 02-2250-0516     축구
# 1076       망우청소년수련관                  02-492-7942     농구
# 1081       중랑청소년수련관                  02-490-0314     탁구
# 1082       중랑청소년수련관                  02-490-0314  당구포켓볼
# 1085       마포청소년수련관                 02-3153-5915     헬스
# 1089       마포청소년수련관                 02-3153-5915     요가
# 1113      서대문청소년수련관                  02-334-0409     수영
# 1125       송파청소년수련관                  02-449-0203     농구
# 1140       용산청소년수련관                  02-749-0103    인라인
# 1211        영롱이억새구장                 02-2670-3522     축구
# 1288      동대문청소년수련관                 02-3295-1478     댄스
# 1290      동대문청소년수련관                 02-3295-1478     농구
# 1296      보라매청소년수련관          02-834-7231(내선1800)     체조
# 1297      보라매청소년수련관          02-834-7231(내선1800)     헬스
# 1307        탄천물재생센터   02-3410-9738/011-9114-3633   배드민턴
# 1308        탄천물재생센터   02-3410-9738/011-9114-3633     풋살
#
#                                       선별방법(선착순-1,추첨순-2)
# 13                      관내(중랑구민/중랑구내 사업체)- 1 관외(타지역)- 2
# 15                      관내(중랑구민/중랑구내 사업체)- 1 관외(타지역)- 2
# 19                                              선착순 예약제
# 21                                               인터넷접수가
# 22                           인터넷접수가 운동시간 예약제로 사전 부킹을 우선
# 23                                              인터넷 접수가
# 24                                              인터넷 접수가
# 35                                                 전화예약
# 40                                              선착순 예약제
# 42                                            비예약 자율이용제
# 43                                            비예약 자율이용제
# 44                                              선착순 예약제
# 46                                    축구교실 우선/비예약 자율이용제
# 47                                            비예약 자율이용제
# 48                                            비예약 자율이용제
# 69                                     1(매월 15일 선착순 접수)
# 70           매월1일(휴일의 경우 익일) 익월 1개월분까지 선착순 접수후 잔여분 전화접수
# 71                      1(매월 9일 10:00부터 인터넷/이용일 2일내 유선)
# 72                           1(매월 19일부터 인터넷/이용일 2일내 유선)
# 79                      1(매월 9일 10:00부터 인터넷/이용일 2일내 유선)
# 120    ① 사용신청서 접수\r 　 - 추첨 후 선착순 전화 신청 (문의 02)360-86...
# 121               공개 추첨을 원칙으로 함.\r 추첨 참가 자격은 등록팀에 한함\r
# 128                              예약방법-홈페이지예약신청후팩스전송방문접수
# 134                                             2(공개추첨)
# 144                                          인터넷 선착순 예약
# 148                                           인터넷 예약 접수
# 160                                                   2
# 164                                                   1
# 166                                               인터넷예약
# 169                       인터넷전화? 방문(심사를 거친후 예약이 완료됩니다.)
# ...                                                 ...
# 969                                                   1
# 978                                                   1
# 980                                                   1
# 981                                                   1
# 982                                                   1
# 985                                                   1
# 1042                                                  1
# 1043                                                  1
# 1047                                                선착순
# 1060             테니스장 및 족구장은 사전예약제로 운영되며 2주전부터 예약을 받습니다
# 1061          테니스장 및 족구장은 사전예약제로 운영되며 2주전부터 예약을 받습니다\r
# 1063                                               선착순
# 1065                        사전예약자가 없을 경우 당일 사용신청도 가능합니다
# 1066                                                  1
# 1070                                     신청서 작성 후 승인 심사
# 1076                                                  1
# 1081                                                  1
# 1082                                                  1
# 1085                                          체육대회 각종행사
# 1089                                           생활체육프로그램
# 1113                                                  1
# 1125                                                  1
# 1140            홈페이지 대관신청서 다운로드 작성 후 FAX:02-749-0223 접수
# 1211                                               인터넷
# 1288                                                  1
# 1290                                                  1
# 1296                                                  1
# 1297                                                  1
# 1307                        사전예약자가 없을 경우 당일 사용신청도 가능합니다
# 1308                     - 사전예약자가 없을 경우 당일 사용신청도 가능합니다.
#
# [208 rows x 4 columns]

# %%
f_public_T1.to_csv('f_public_T1.csv')

# %%
# !ls
# Out:
# Crawling_practice.ipynb  c_public_T1.csv          programDetail.json
# Crawling_practice2.ipynb c_public_T1.xlsx         programList.csv
# Crawling_real.ipynb      f_public_T1 2.xlsx       programList.json
# Crawling_real_2.ipynb    f_public_T1.csv          sqllite3.py
# Crawling_real_4.ipynb    paramDetail.csv          test2.sqlite
# M_park_T1.csv            paramList.csv
# M_park_T1.xlsx           paramList.txt

# %%
#f_public_f1.pivot
#f_public_f1.groupby('시설명').count()
#f_public_f.groupby('종목시설명').count()
#f_public_f.groupby('종목시설명')

# %% [markdown]
# ### 공공체육시설-종목별

# %%
#웹드라이버 실행 및 페이지 이동
driver = webdriver.Chrome()
driver.get(crawling_urls['공공체육시설_종목별'])
time.sleep(10)

driver.find_element_by_css_selector("#tabSheet").click()
time.sleep(5)
    
#csv파일 다운로드 버튼 클릭하기
driver.find_element_by_css_selector("#Wrapfilter > span:nth-child(3)").click()
time.sleep(5)

driver.quit()

# %%
#다운받은 csv파일 열기
_dir = "/Users/jooyoungson/Downloads/"
files = glob.glob('{}/*.csv'.format(_dir))
print(files)

#csv파일을 dataframe으로 변환하기
f_public_c= pd.read_csv(files[len(files)-1])
f_public_c.head(3)
# Out:
# ['/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어) (1).csv', '/Users/jooyoungson/Downloads/서울시 공공 체육시설별 운영프로그램 정보.csv', '/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어).csv', '/Users/jooyoungson/Downloads/서울시 산과공원 생태관광 정보 (한국어) (2).csv', '/Users/jooyoungson/Downloads/서울시 공공 체육시설별 종목시설명 정보.csv']
#           시설명  일련번호          시설키   종목시설명           종목시설키   종목명 종목키   위치 면적(㎡)  \
# 0      영희초등학교   433  GN10100PUSM     체육관  GN10100PUSM101  학교체육  SG  NaN   NaN
# 1      포이초등학교   438  GN10101PUSM     헬스장  GN10101PUSM103    헬스  HE  NaN   NaN
# 2  한강시민공원강서지구   615  GS10173PUEF  체력단련기구  GS10173PUEF104    헬스  HE  NaN   NaN
#
#     규격  ... 이용기간                                               이용시간 이용료(원)  \
# 0  NaN  ...  NaN                                                NaN    NaN
# 1  NaN  ...  NaN                                                NaN    NaN
# 2  NaN  ...  NaN  06:00~20:00(4~9월 : 06:00~20:00 1~3 10~12월 : 07...    NaN
#
#     용도   비고 대관링크주소                                              이미지파일  \
# 0  NaN  NaN    NaN                                                NaN
# 1  NaN  NaN    NaN                                                NaN
# 2  NaN  NaN    NaN  http://hangang.seoul.go.kr/park_gangseo/images...
#
#   선별방법(선착순-1,추첨순-2) 유의사항 이용단위
# 0               NaN  NaN  NaN
# 1               NaN  NaN  NaN
# 2               NaN  NaN  NaN
#
# [3 rows x 24 columns]

# %%
f_public_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 24 columns):
# 시설명                  1310 non-null object
# 일련번호                 1310 non-null int64
# 시설키                  1310 non-null object
# 종목시설명                1310 non-null object
# 종목시설키                1310 non-null object
# 종목명                  1302 non-null object
# 종목키                  1303 non-null object
# 위치                   849 non-null object
# 면적(㎡)                428 non-null object
# 규격                   411 non-null object
# 연면적(㎡)               107 non-null object
# 문의전화                 515 non-null object
# 수용인원(정원)             70 non-null object
# 이용대상                 252 non-null object
# 이용기간                 121 non-null object
# 이용시간                 320 non-null object
# 이용료(원)               303 non-null object
# 용도                   188 non-null object
# 비고                   306 non-null object
# 대관링크주소               121 non-null object
# 이미지파일                825 non-null object
# 선별방법(선착순-1,추첨순-2)    222 non-null object
# 유의사항                 263 non-null object
# 이용단위                 240 non-null object
# dtypes: int64(1), object(23)
# memory usage: 245.7+ KB

# %%
f_public_c.columns
# Out:
# Index(['시설명', '일련번호', '시설키', '종목시설명', '종목시설키', '종목명', '종목키', '위치', '면적(㎡)',
#        '규격', '연면적(㎡)', '문의전화', '수용인원(정원)', '이용대상', '이용기간', '이용시간', '이용료(원)',
#        '용도', '비고', '대관링크주소', '이미지파일', '선별방법(선착순-1,추첨순-2)', '유의사항', '이용단위'],
#       dtype='object')

# %%
f_public_c1 = f_public_c[['시설명','문의전화','종목명','대관링크주소','선별방법(선착순-1,추첨순-2)']]
f_public_c1
c_public_T= f_public_c1.dropna(axis=0)
#종목시설명은 시설명 내의 위치를 설명하므로 뺀다. 
c_public_T
# Out:
#               시설명                       문의전화   종목명  \
# 21          월드컵공원                02-300-5521    축구
# 22          월드컵공원               02-304-3212     골프
# 24          월드컵공원                02-300-5521   테니스
# 144         뚝섬서울숲                02-460-2907    축구
# 148         뚝섬서울숲                02-460-2907   테니스
# 160   한강시민공원광나루지구               02-3780-0501    야구
# 169    구의야구공원 야구장               02-3436-2889    야구
# 176        어린이대공원                02-457-8718    풋살
# 177        어린이대공원                02-457-8718    풋살
# 288         보라매공원               02-2181-1186    축구
# 493      목동다목적경기장               02-2640-3802    축구
# 499      창동문화체육센터                02-901-5249    축구
# 502      창동문화체육센터                02-901-5226  에어로빅
# 504      창동문화체육센터                02-901-5226    요가
# 505      창동문화체육센터                02-901-5226    탁구
# 528       올림픽주경기장        02-2240-8746 / 8712    축구
# 529       잠실보조경기장              02-2240-8712     축구
# 531         잠실체육관               02-2240-8809    농구
# 533        잠실1수영장               02-2240-8963    수영
# 534        잠실2수영장               02-2240-8966    수영
# 537      잠실인라인하키장               02-2240-8936   인라인
# 538       잠실풋살경기장               02-2240-8970    풋살
# 539        목동주경기장               02-2640-3808    축구
# 540         목동야구장               02-2640-3808    야구
# 545      개운산스포츠센터              02-925-9960~2    댄스
# 560       강북구민운동장                02-944-2914    축구
# 561       강북구민운동장                02-944-2914    족구
# 570     강북웰빙스포츠센터                02-944-2914    수영
# 574     강북웰빙스포츠센터                02-944-2914  배드민턴
# 576     강북웰빙스포츠센터                02-944-2914  배드민턴
# 633    금천구민문화체육센터                02-861-1313    농구
# 640     온조대왕문화체육관               02-2045-7821  배드민턴
# 641     온조대왕문화체육관               02-2045-7821  에어로빅
# 642     온조대왕문화체육관               02-2045-7821    탁구
# 650      해공체육문화센터                02-477-2229  배드민턴
# 651      해공체육문화센터                02-477-2229    댄스
# 717        무학봉체육관               02-2260-1566  배드민턴
# 769       관악구민운동장  02-2081-2660 02)882-2660     축구
# 782       난지물재생센터              02-300-8508~9   테니스
# 783       난지물재생센터              02-300-8508~9    족구
# 784       난지물재생센터              02-300-8508~9    배구
# 785       난지물재생센터              02-300-8508~9    탁구
# 786       난지물재생센터              02-300-8508~9    축구
# 805    동대문종합사회복지관                02-926-3013  에어로빅
# 806    동대문종합사회복지관                02-926-3013    헬스
# 809    동대문종합사회복지관                02-926-3013  배드민턴
# 810       영롱이갈대구장               02-2670-3522    축구
# 814       영롱이갈대구장               02-2670-3522    축구
# 839       해누리체육공원               02-2652-3458    축구
# 846       영롱이갈대구장               02-2670-3522    축구
# 859    동대문종합사회복지관                02-926-3013    수영
# 860     면목종합사회복지관                02-926-3013    검도
# 961      수서청소년수련관  02-2226-3611~4(내선 501~2번)    헬스
# 1047      영롱이억새구장               02-2670-3522    축구
# 1063      영롱이억새구장               02-2670-3522    축구
# 1211      영롱이억새구장               02-2670-3522    축구
# 1288    동대문청소년수련관               02-3295-1478    댄스
# 1290    동대문청소년수련관               02-3295-1478    농구
#
#                                                  대관링크주소  \
# 21    http://worldcuppark.seoul.go.kr/guide/sports2_...
# 22    https://strawberry.mainticket.co.kr/strawberry...
# 24    http://worldcuppark.seoul.go.kr/guide/sports2_...
# 144   http://parks.seoul.go.kr/template/common/reser...
# 148   http://parks.seoul.go.kr/template/common/reser...
# 160                   http://yeyak.seoul.go.kr/main.web
# 169   http://stadium.seoul.go.kr/reserve/reserve_04....
# 176                   http://www.sraf.kr/reserv_ok.html
# 177                   http://www.sraf.kr/reserv_ok.html
# 288   http://parks.seoul.go.kr/template/common/reser...
# 493    http://stadium.seoul.go.kr/hockey/inline_02.html
# 499   http://www.dobongsiseol.or.kr/sub05/sub05_a_01...
# 502   http://www.dobongsiseol.or.kr/sub05/sub05_a_01...
# 504   http://www.dobongsiseol.or.kr/sub05/sub05_a_01...
# 505   http://www.dobongsiseol.or.kr/sub05/sub05_a_01...
# 528   http://stadium.seoul.go.kr/reserve/reserve_04....
# 529   http://stadium.seoul.go.kr/reserve/reserve_04....
# 531   http://stadium.seoul.go.kr/reserve/reserve_04....
# 533   http://stadium.seoul.go.kr/reserve/reserve_04....
# 534   http://stadium.seoul.go.kr/reserve/reserve_04....
# 537    http://stadium.seoul.go.kr/hockey/inline_02.html
# 538    http://stadium.seoul.go.kr/hockey/inline_02.html
# 539   http://stadium.seoul.go.kr/reserve/reserve_04....
# 540   http://stadium.seoul.go.kr/reserve/reserve_04....
# 545   http://sports.gongdan.go.kr/gus_sports/intro/i...
# 560   http://www.gangbukcmc.seoul.kr/sports/group03/...
# 561   http://www.gangbukcmc.seoul.kr/sports/group03/...
# 570   http://www.gangbukcmc.seoul.kr/sports/group04/...
# 574   http://www.gangbukcmc.seoul.kr/sports/group04/...
# 576   http://www.gangbukcmc.seoul.kr/sports/group04/...
# 633                 http://www.gfmc.co.kr/sub3/01_5.asp
# 640                 http://www.onjo.or.kr/use/use04.asp
# 641                 http://www.onjo.or.kr/use/use04.asp
# 642                 http://www.onjo.or.kr/use/use04.asp
# 650     http://haegonggym.igangdong.or.kr/use/use01.asp
# 651     http://haegonggym.igangdong.or.kr/use/use01.asp
# 717      http://www.e-junggu.or.kr/?code=10&subp=2020_2
# 769   http://www.gwanakgongdan.or.kr/rent/rent_perio...
# 782   http://nanji.seoul.go.kr/preengage/preengage02...
# 783   http://nanji.seoul.go.kr/preengage/preengage02...
# 784   http://nanji.seoul.go.kr/preengage/preengage02...
# 785   http://nanji.seoul.go.kr/preengage/preengage02...
# 786   http://nanji.seoul.go.kr/preengage/preengage02...
# 805   http://www.communitycenter.or.kr/board/acc_boa...
# 806   http://www.communitycenter.or.kr/board/acc_boa...
# 809   http://www.communitycenter.or.kr/board/acc_boa...
# 810                   http://yeyak.seoul.go.kr/main.web
# 814                   http://yeyak.seoul.go.kr/main.web
# 839   http://www.ycs.or.kr/rent/rent_plan_list.php?c...
# 846                   http://yeyak.seoul.go.kr/main.web
# 859   http://www.communitycenter.or.kr/board/acc_boa...
# 860   http://www.communitycenter.or.kr/board/acc_boa...
# 961   http://www.youtra.or.kr:9090/suseo/infomation/...
# 1047                  http://yeyak.seoul.go.kr/main.web
# 1063                  http://yeyak.seoul.go.kr/main.web
# 1211                  http://yeyak.seoul.go.kr/main.web
# 1288  이메일 신청(rent@youthi.net) http://www.ddmy.or.kr/...
# 1290  이메일 신청(rent@youthi.net)http://www.ddmy.or.kr/i...
#
#                                       선별방법(선착순-1,추첨순-2)
# 21                                               인터넷접수가
# 22                           인터넷접수가 운동시간 예약제로 사전 부킹을 우선
# 24                                              인터넷 접수가
# 144                                          인터넷 선착순 예약
# 148                                           인터넷 예약 접수
# 160                                                   2
# 169                       인터넷전화? 방문(심사를 거친후 예약이 완료됩니다.)
# 176   어린이 · 유소년축구(12세 이하)(어린이 · 유소년 축구팀 포함) 시장배 어린이 ...
# 177   어린이 · 유소년축구(12세 이하)(어린이 · 유소년 축구팀 포함) 시장배 어린이 ...
# 288                                                   1
# 493                                      상시 인터넷 선착순 예약
# 499                                                 선착순
# 502                                       전화예약신청 및 현장접수
# 504                                                   1
# 505                                                 선착순
# 528                      인터넷 / 방문 (심사를 거친후 예약이 완료됩니다.)
# 529                      인터넷 / 방문 (심사를 거친후 예약이 완료됩니다.)
# 531               접수방법:인터넷 / 방문 *심사(심사를 거친후 예약이 완료됩니다.)
# 533                                                선착순
# 534               접수방법:인터넷 / 방문 *심사(심사를 거친후 예약이 완료됩니다.)
# 537                                           전화예약 홈페이지
# 538                                             선착순/인터넷
# 539               접수방법:인터넷 / 방문 *심사(심사를 거친후 예약이 완료됩니다.)
# 540               접수방법:인터넷 / 방문 *심사(심사를 거친후 예약이 완료됩니다.)
# 545                            1(사전상담-신청서작성-1층안내데스크 접수)
# 560   배정순위접수/제출서류 : 팀등록 접수시 회원명부 주민등록증사본 *신청서작성(사용료 ...
# 561   배정순위접수/제출서류 : 팀등록 접수시 회원명부 주민등록증사본 *신청서작성(사용료 ...
# 570                                                 선착순
# 574                                                 선착순
# 576                                                 선착순
# 633                                                   1
# 640                                                 선착순
# 641                                                 선착순
# 642                                                 선착순
# 650                                                 선착순
# 651                                                 선착순
# 717                                                 선착순
# 769                           관악주민:2 기타:관악주민:관악주민 후 선착순
# 782                          인터넷으로 온라인신청 또는 전화예약 및 방문접수
# 783                          인터넷으로 온라인신청 또는 전화예약 및 방문접수
# 784                          인터넷으로 온라인신청 또는 전화예약 및 방문접수
# 785                          인터넷으로 온라인신청 또는 전화예약 및 방문접수
# 786                          인터넷으로 온라인신청 또는 전화예약 및 방문접수
# 805                                                 선착순
# 806                                                 선착순
# 809                                                 선착순
# 810                                                선착순
# 814                                                선착순
# 839   ○ 순위 : 팀등록 완료된 관내팀→ 관외팀 → 미등록팀                ...
# 846                                                 선착순
# 859                                                 선착순
# 860                                                 선착순
# 961                                                   1
# 1047                                                선착순
# 1063                                               선착순
# 1211                                               인터넷
# 1288                                                  1
# 1290                                                  1

# %%
c_public_T.to_csv('c_public_T1.csv')

# %% [markdown]
# ## 체육시설 시설별, 종목별 합치기

# %%
c_public_T['시설명']
# Out:
# 21            월드컵공원
# 22            월드컵공원
# 24            월드컵공원
# 144           뚝섬서울숲
# 148           뚝섬서울숲
# 160     한강시민공원광나루지구
# 169      구의야구공원 야구장
# 176          어린이대공원
# 177          어린이대공원
# 288           보라매공원
# 493        목동다목적경기장
# 499        창동문화체육센터
# 502        창동문화체육센터
# 504        창동문화체육센터
# 505        창동문화체육센터
# 528         올림픽주경기장
# 529         잠실보조경기장
# 531           잠실체육관
# 533          잠실1수영장
# 534          잠실2수영장
# 537        잠실인라인하키장
# 538         잠실풋살경기장
# 539          목동주경기장
# 540           목동야구장
# 545        개운산스포츠센터
# 560         강북구민운동장
# 561         강북구민운동장
# 570       강북웰빙스포츠센터
# 574       강북웰빙스포츠센터
# 576       강북웰빙스포츠센터
# 633      금천구민문화체육센터
# 640       온조대왕문화체육관
# 641       온조대왕문화체육관
# 642       온조대왕문화체육관
# 650        해공체육문화센터
# 651        해공체육문화센터
# 717          무학봉체육관
# 769         관악구민운동장
# 782         난지물재생센터
# 783         난지물재생센터
# 784         난지물재생센터
# 785         난지물재생센터
# 786         난지물재생센터
# 805      동대문종합사회복지관
# 806      동대문종합사회복지관
# 809      동대문종합사회복지관
# 810         영롱이갈대구장
# 814         영롱이갈대구장
# 839         해누리체육공원
# 846         영롱이갈대구장
# 859      동대문종합사회복지관
# 860       면목종합사회복지관
# 961        수서청소년수련관
# 1047        영롱이억새구장
# 1063        영롱이억새구장
# 1211        영롱이억새구장
# 1288      동대문청소년수련관
# 1290      동대문청소년수련관
# Name: 시설명, dtype: object

# %%
f_public_T1['시설명']
# Out:
# 13             용마폭포공원
# 15          중랑구립잔디운동장
# 19            안양천체육시설
# 21              월드컵공원
# 22              월드컵공원
# 23              월드컵공원
# 24              월드컵공원
# 35             목동테니스장
# 40            안양천체육시설
# 42            안양천체육시설
# 43            안양천체육시설
# 44            안양천체육시설
# 46            안양천체육시설
# 47            안양천체육시설
# 48            안양천체육시설
# 69         공릉동다목적풋살구장
# 70          노해근린공원운동장
# 71             마들스타디움
# 72             마들스타디움
# 79            초안산근린공원
# 120       서대문구립인조잔디구장
# 121        송파구여성전용축구장
# 128          올림픽올팍축구장
# 134           천마공원축구장
# 144             뚝섬서울숲
# 148             뚝섬서울숲
# 160       한강시민공원광나루지구
# 164          근로청소년복지관
# 166     동명근린공원인조잔디축구장
# 169        구의야구공원 야구장
#             ...
# 969          역삼청소년수련관
# 978          금천청소년수련관
# 980           강동청소년회관
# 981           강동청소년회관
# 982           강동청소년회관
# 985          역삼청소년수련관
# 1042         화곡청소년수련관
# 1043         서울청소년수련관
# 1047          영롱이억새구장
# 1060          탄천물재생센터
# 1061          탄천물재생센터
# 1063          영롱이억새구장
# 1065          탄천물재생센터
# 1066         화곡청소년수련관
# 1070         중구청소년수련관
# 1076         망우청소년수련관
# 1081         중랑청소년수련관
# 1082         중랑청소년수련관
# 1085         마포청소년수련관
# 1089         마포청소년수련관
# 1113        서대문청소년수련관
# 1125         송파청소년수련관
# 1140         용산청소년수련관
# 1211          영롱이억새구장
# 1288        동대문청소년수련관
# 1290        동대문청소년수련관
# 1296        보라매청소년수련관
# 1297        보라매청소년수련관
# 1307          탄천물재생센터
# 1308          탄천물재생센터
# Name: 시설명, Length: 208, dtype: object

# %%
#a = pd.merge(c_public_T, f_public_T1)

# %%
# !ls
# Out:
# Crawling_practice.ipynb  Crawling_real_2.ipynb    f_public_T1.csv
# Crawling_practice2.ipynb Crawling_real_3.ipynb    sqllite3.py
# Crawling_real.ipynb      c_public_T1.csv          test2.sqlite

# %%
# !pwd
# Out:
# /Users/jooyoungson/Documents/GitHub/2019/SonJooyoung

# %% [markdown]
# ## 서울특별시체육회 시민참여프로그램

# %% [markdown]
# #### 시민 참여프로그램 목록

# %%
import requests
from bs4 import BeautifulSoup
import json
import os

BASE_DIR = '/Users/jooyoungson/Documents/GitHub/2019/SonJooyoung'

req = requests.get('https://www.seoulsports.or.kr/home/homeIndex.do')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
programs = soup.select('#gnb > div > div > div > ul.mo-gnb > li:nth-child(1) > ul > li > a')

for program in programs:
    print('프로그램 : {} , href태그 : {}'.format(program.text,  program.get('href')))
    
data = {}
for program in programs:
    data[program.text] = program.get('href')
    
# csv 파일로 저장   
f = open('paramList.csv','w')
f.write(str(data))
f.close()  

# json 파일로 저장   
with open(os.path.join(BASE_DIR, 'programList.json'), 'w+') as json_file:
    json.dump(data, json_file)
# Out:
# 프로그램 : 서울트레킹 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=traking
# 프로그램 : 스포츠재능나눔 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=sharetalent
# 프로그램 : 가족스케이팅교실 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=skating
# 프로그램 : 종목별스포츠교실-봅슬레이 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=stsixt
# 프로그램 : 가족파크골프교실 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=parkgolf
# 프로그램 : 가족스포츠캠프 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=camp
# 프로그램 : 서바이벌프로그램 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=survival
# 프로그램 : 종목별스포츠교실-럭비 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=stten
# 프로그램 : 종목별스포츠교실-카누 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=stthirt
# 프로그램 : 종목별스포츠교실-족구 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=stele
# 프로그램 : 스포츠재능나눔-스킨스쿠버 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=stfive
# 프로그램 : 가족수상스포츠교실 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=famliy
# 프로그램 : 찾아가는 체육관 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=gym
# 프로그램 : 축구심판양성교육 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=lsl
# 프로그램 : 시민대상낚시교실 , href태그 : /user/citizenAction/userCitizenProgramList.do?citizenParam=stfift

# %%
#h = pd.read_csv('paramList.csv','w')
#h.head()
# Out:
# Empty DataFrame
# Columns: [{'서울트레킹': '/user/citizenAction/userCitizenProgramList.do?citizenParam=traking', '스포츠재능나눔': '/user/citizenAction/userCitizenProgramList.do?citizenParam=sharetalent', '가족스케이팅교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=skating', '종목별스포츠교실-봅슬레이': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stsixt', '가족파크골프교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=parkgolf', '가족스포츠캠프': '/user/citizenAction/userCitizenProgramList.do?citizenParam=camp', '서바이벌프로그램': '/user/citizenAction/userCitizenProgramList.do?citizenParam=survival', '종목별스포츠교실-럭비': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stten', '종목별스포츠교실-카누': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stthirt', '종목별스포츠교실-족구': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stele', '스포츠재능나눔-스킨스쿠버': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stfive', '가족수상스포츠교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=famliy', '찾아가는 체육관': '/user/citizenAction/userCitizenProgramList.do?citizenParam=gym', '축구심판양성교육': '/user/citizenAction/userCitizenProgramList.do?citizenParam=lsl', '시민대상낚시교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stfift'}]
# Index: []

# %%
# !pwd
# Out:
# /Users/jooyoungson/Documents/GitHub/2019/SonJooyoung

# %%
proName = None

with open(r'/Users/jooyoungson/Documents/GitHub/2019/SonJooyoung/programList.json', 'r') as f:
    proName = json.load(f)
    
print(proName)
# Out:
# {'서울트레킹': '/user/citizenAction/userCitizenProgramList.do?citizenParam=traking', '스포츠재능나눔': '/user/citizenAction/userCitizenProgramList.do?citizenParam=sharetalent', '가족스케이팅교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=skating', '종목별스포츠교실-봅슬레이': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stsixt', '가족파크골프교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=parkgolf', '가족스포츠캠프': '/user/citizenAction/userCitizenProgramList.do?citizenParam=camp', '서바이벌프로그램': '/user/citizenAction/userCitizenProgramList.do?citizenParam=survival', '종목별스포츠교실-럭비': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stten', '종목별스포츠교실-카누': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stthirt', '종목별스포츠교실-족구': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stele', '스포츠재능나눔-스킨스쿠버': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stfive', '가족수상스포츠교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=famliy', '찾아가는 체육관': '/user/citizenAction/userCitizenProgramList.do?citizenParam=gym', '축구심판양성교육': '/user/citizenAction/userCitizenProgramList.do?citizenParam=lsl', '시민대상낚시교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stfift'}

# %% [markdown]
# #### 접수중인 프로그램 목록

# %%
proList = ['traking', 'sharetalent', 'skating', 'stsixt', 'parkgolf',
           'camp', 'survival', 'stten', 'stthirt', 'stele', 'stfive',
           'workleague', 'family', 'gym', 'lsl', 'stfift']

# '서울트레킹' : 'traking',
# '스포츠재능나눔' : 'sharetalent',
# '가족스케이팅교실' : 'skating',
# '종목별스포츠교실-봅슬레이' : 'stsixt',
# '가족파크골프교실' : 'parkgolf',
# '가족스포츠캠프' : 'camp',
# '서바이벌프로그램' : 'survival',
# '종목별스포츠교실-럭비' : 'stten',
# '종목별스포츠교실-카누' : 'stthirt',
# '종목별스포츠교실-족구' : 'stele',
# '스포츠재능나눔-스킨스쿠버' : 'stfive',
# '직장인리그' : 'workleague',
# '가족수상스포츠교실' : 'family',
# '찾아가는 체육관' : 'gym',
# '축구심판양성교육' : 'lsl',
# '시민대상낚시교실' : 'stfift'

programListLink = "https://www.seoulsports.or.kr/user/citizenAction/userCitizenProgramList.do?citizenParam="

for i in range(len(proList)):
    req = requests.get(programListLink + "{}".format(proList[i]))
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')
    
    programs = soup.select('#content > div.table-wrap > ul > li')
    for p in programs:
        if('접수중' in p.text):
            print("done")
#            print(p.text)
# Out:
# done

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# # 크롬 headless 모드 실행
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument('headless')
# chrome_options.add_argument('--disable-gpu')
# chrome_options.add_argument('lang=ko_KR')

driver = webdriver.Chrome()
# 암묵적으로 웹 자원 로드를 위해 3초까지 기다려 준다.
driver.implicitly_wait(3)

# url에 접근
driver.get('https://www.seoulsports.or.kr/home/homeIndex.do')

# 메뉴 클릭 후 시민참여프로그램 클릭
driver.find_element_by_xpath('//*[@id="gnb"]/div[1]/button/img').click()
driver.find_element_by_xpath('//*[@id="gnb"]/div[1]/div/div/ul[2]/li[1]/a').click()

# 시민참여프로그램 리스트 가져오기
req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')
programList = soup.select('#gnb > div:nth-child(2) > div > div > ul.mo-gnb > li:nth-child(1) > ul > li > a')

data1 = {}

# 시민참여프로그램 중 '접수중'인 프로그램 찾기
for i in range(len(programList)-1):
    if(i == 0):
        driver.find_element_by_xpath('//*[@id="gnb"]/div[1]/div/div/ul[2]/li[1]/ul/li[1]/a').click()

    req = driver.page_source
    soup = BeautifulSoup(req, 'html.parser')
    programs = soup.select('#content > div.table-wrap > ul > li')
    
    for p in programs:
        if('접수중' in p.text):
            data1[programList[i].text] = p.text
            print(p.text)
    driver.find_element_by_xpath('//*[@id="content"]/a[2]').click()

# # json 파일로 저장
# with open(os.path.join(BASE_DIR, 'programDetail.json'), 'w+') as json_file:
#     json.dump(data, json_file)

# proName = None

# with open(r'/Users/jooyoungson/Documents/GitHub/2019/SonJooyoung/programDetail.json', 'r') as f:
#     proName = json.load(f)

#csv파일로 저장
f1 = open('paramDetail.csv','w')
f1.write(str(data1))
f1.close()
# Out:
# 접수중
#
#
#
# 					★접수중★서울트레킹 5차
#
#
#
#
#
#
#
# 						2019 서울트레킹(5차) 일정안내
#
# ■ 행사일자 : 2019.10.12.(토) 09:00
# ■ 모집기간 : 9. 30.(월) 10:00 ~ 10. 10.(목) 17:00
#
#   ※ 모바일 접수시, 오류가 발생할 수 있으니 PC로 접수해 주시기 바랍니다.
#
# ■ 집결장소 : 송파구 방이동 올림픽공원 88호수 수변무대
# ■ 참여대상 : 서울시민이면 누구나 (단, 초등학생 이상)
# ■ 소요시간 : 약 1시간 30분 (3.9km)
# ■ 난이도 : 중하
#
# ▣ 현장접수는 따로 받지 않습니다.
# ▣ 신청 후 마이페이지에서 신청 인원 확인 必
#
#
#
# 문의) 02-490-2767
#
#
# 장소보기

# %%
# !ls
# Out:
# Crawling_practice.ipynb  M_park_T1.xlsx           paramList.csv
# Crawling_practice2.ipynb c_public_T1.csv          programDetail.json
# Crawling_real.ipynb      c_public_T1.xlsx         programList.csv
# Crawling_real_2.ipynb    f_public_T1 2.xlsx       programList.json
# Crawling_real_4.ipynb    f_public_T1.csv          sqllite3.py
# M_park_T1.csv            paramDetail.csv          test2.sqlite

# %%
f = pd.read_csv('paramList.csv')
f1 = pd.read_csv('paramDetail.csv')

# %%
f.head()
# Out:
# Empty DataFrame
# Columns: [{'서울트레킹': '/user/citizenAction/userCitizenProgramList.do?citizenParam=traking',  '스포츠재능나눔': '/user/citizenAction/userCitizenProgramList.do?citizenParam=sharetalent',  '가족스케이팅교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=skating',  '종목별스포츠교실-봅슬레이': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stsixt',  '가족파크골프교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=parkgolf',  '가족스포츠캠프': '/user/citizenAction/userCitizenProgramList.do?citizenParam=camp',  '서바이벌프로그램': '/user/citizenAction/userCitizenProgramList.do?citizenParam=survival',  '종목별스포츠교실-럭비': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stten',  '종목별스포츠교실-카누': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stthirt',  '종목별스포츠교실-족구': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stele',  '스포츠재능나눔-스킨스쿠버': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stfive',  '가족수상스포츠교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=famliy',  '찾아가는 체육관': '/user/citizenAction/userCitizenProgramList.do?citizenParam=gym',  '축구심판양성교육': '/user/citizenAction/userCitizenProgramList.do?citizenParam=lsl',  '시민대상낚시교실': '/user/citizenAction/userCitizenProgramList.do?citizenParam=stfift'}]
# Index: []

# %%
f1.head()
# Out:
# Empty DataFrame
# Columns: [{'서울트레킹': '\n\n\n\n\n\n\n접수중\n\n\n\n\t\t\t\t\t★접수중★서울트레킹 5차\n\t\t\t\t\t\n\n\n\n\n\n\t\t\t\t\t\n\t\t\t\t\t\t2019 서울트레킹(5차) 일정안내\n\n■ 행사일자 : 2019.10.12.(토) 09:00\n■ 모집기간 : 9. 30.(월) 10:00 ~ 10. 10.(목) 17:00 \n\n  ※ 모바일 접수시,  오류가 발생할 수 있으니 PC로 접수해 주시기 바랍니다.  \n\n■ 집결장소 : 송파구 방이동 올림픽공원 88호수 수변무대\n■ 참여대상 : 서울시민이면 누구나 (단,  초등학생 이상) \n■ 소요시간 : 약 1시간 30분 (3.9km)\n■ 난이도 : 중하\n\n▣ 현장접수는 따로 받지 않습니다.\n▣ 신청 후 마이페이지에서 신청 인원 확인 必\n\n\n\n문의) 02-490-2767 \n\t\t\t\t\t\n\n장소보기\n\n'}]
# Index: []
